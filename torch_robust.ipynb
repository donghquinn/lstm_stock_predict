# %%
import torch
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("stock.csv")
data
# Out:
#            Open        High         Low   Volume       Close
# 0    828.659973  833.450012  828.349976  1247700  831.659973
# 1    823.020020  828.070007  821.655029  1597800  828.070007
# 2    819.929993  824.400024  818.979980  1281700  824.159973
# 3    819.359985  823.000000  818.469971  1304000  818.979980
# 4    819.000000  823.000000  816.000000  1053600  820.450012
# ..          ...         ...         ...      ...         ...
# 727  599.992707  604.832763  562.192568   147100  567.002574
# 728  558.712504  568.452595  558.712504     7900  567.162558
# 729  566.892592  567.002574  556.932537    10800  556.972503
# 730  561.202549  566.432590  558.672539    41200  559.992565
# 731  568.002570  568.002570  552.922516    13100  558.462551
#
# [732 rows x 5 columns]

# %%
size = len(data)
size
# Out:
# 732

# %%
price = data["Close"].values.astype(float)

# %% [markdown]
# # 데이터 스케일링
#
# 스케일링은 특성들이 서로 다른 범위를 가지고 있을 때, 동일한 범위의 값을 가질 수 있게 스케일링 하는 것을 의미.
#
# >예시
# * x1은 0 ~ 1 사이의 값을 가지고
# * x2는 1000 ~ 100000 사이의 값을 가지며
# * y는 100000 ~ 10000000 사이의 값을 가진다면
# >
#
# x1의 값은 y의 결과치에 영향을 주지 못함. 따라서 같은 범위 내의 값들로 변환시킬 필요가 있음.
#
# * 정규화 Normalization
#   - 이상치에 민감.
#   - 분류보다 회귀에 적합.
#   - 최대값 1, 최솟값 0으로 크기를 제한.
#   - 즉 값이 0~1 사이의 값이 나온다.
#
# * 표준화 Standardization
#   - 이상치에 민감.
#   - 회귀보다 분류에 적합.
#   - 평균을 0, 분산을 1로 스케일링.
#   - 최댓값 및 최솟값의 크기를 제한하지 않음.

# %%
from sklearn.preprocessing import RobustScaler

# Scaling - 로버스틱 방식(이상치 영향 적음)
scaler_x = RobustScaler()
price = scaler_x.fit_transform(price.reshape(-1, 1))

# %% [markdown]
# # 훈련 - 학습 데이터 분리

# %%
from sklearn.model_selection import train_test_split

X, y = [], []

seq_length = 10

for i in range(len(price) - seq_length):
  X.append(price[i:i+seq_length])
  y.append(price[i+seq_length])

X = np.array(X)
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# # LSTM 모델 정의

# %%
import torch.nn as nn

# LSTM 모델 정의
class StockPredictor(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers):
        super(StockPredictor, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.linear(out[:, -1, :])
        return out

# %%
input_dim = 1
hidden_dim = 64
num_layers = 2

model = StockPredictor(input_dim, hidden_dim, num_layers)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # 훈련

# %%
num_epochs = 100
for epoch in range(num_epochs):
    outputs = model(X_train)
    optimizer.zero_grad()
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        print(f'Epoch: {epoch+1}, Loss: {loss.item()}')
# Out:
# Epoch: 10, Loss: 0.1150452196598053
# Epoch: 20, Loss: 0.07292639464139938
# Epoch: 30, Loss: 0.053822215646505356
# Epoch: 40, Loss: 0.030254926532506943
# Epoch: 50, Loss: 0.0064279185608029366
# Epoch: 60, Loss: 0.005744013004004955
# Epoch: 70, Loss: 0.004311870317906141
# Epoch: 80, Loss: 0.0037505992222577333
# Epoch: 90, Loss: 0.003430562559515238
# Epoch: 100, Loss: 0.003161706728860736

# %% [markdown]
# # 검증 진행

# %%
from sklearn.metrics import mean_squared_error

# 테스트
model.eval()
with torch.no_grad():
    test_outputs = model(X_test)
    mse = mean_squared_error(y_test, test_outputs)
    print(f'Mean Squared Error on Test Data: {mse}')

predicted_prices = scaler_x.inverse_transform(test_outputs.numpy())
actual_prices = scaler_x.inverse_transform(y_test.numpy())

for i in range(len(predicted_prices)):
    print(f"Actual Price: {actual_prices[i][0]:.2f}, Predicted Price: {predicted_prices[i][0]:.2f}")
# Out:
# Mean Squared Error on Test Data: 0.0033427339512854815
# Actual Price: -0.11, Predicted Price: -0.16
# Actual Price: -0.92, Predicted Price: -0.73
# Actual Price: -0.72, Predicted Price: -0.71
# Actual Price: 0.74, Predicted Price: 0.76
# Actual Price: -0.74, Predicted Price: -0.69
# Actual Price: -0.74, Predicted Price: -0.69
# Actual Price: 0.70, Predicted Price: 0.62
# Actual Price: 0.61, Predicted Price: 0.64
# Actual Price: 0.37, Predicted Price: 0.07
# Actual Price: -0.52, Predicted Price: -0.63
# Actual Price: -0.67, Predicted Price: -0.71
# Actual Price: 0.79, Predicted Price: 0.74
# Actual Price: -0.61, Predicted Price: -0.21
# Actual Price: 0.57, Predicted Price: 0.61
# Actual Price: -0.52, Predicted Price: -0.53
# Actual Price: -0.68, Predicted Price: -0.67
# Actual Price: -0.73, Predicted Price: -0.71
# Actual Price: -0.72, Predicted Price: -0.72
# Actual Price: 0.16, Predicted Price: 0.23
# Actual Price: -0.74, Predicted Price: -0.72
# Actual Price: 0.61, Predicted Price: 0.66
# Actual Price: 0.65, Predicted Price: 0.81
# Actual Price: -0.12, Predicted Price: -0.28
# Actual Price: 0.71, Predicted Price: 0.79
# Actual Price: 0.67, Predicted Price: 0.84
# Actual Price: -0.78, Predicted Price: -0.70
# Actual Price: -0.80, Predicted Price: -0.69
# Actual Price: -0.74, Predicted Price: -0.72
# Actual Price: 0.50, Predicted Price: 0.54
# Actual Price: 0.90, Predicted Price: 0.90
# Actual Price: 0.59, Predicted Price: 0.59
# Actual Price: 0.66, Predicted Price: 0.84
# Actual Price: 0.28, Predicted Price: 0.27
# Actual Price: 0.24, Predicted Price: 0.19
# Actual Price: -0.57, Predicted Price: -0.65
# Actual Price: -0.12, Predicted Price: -0.36
# Actual Price: -0.67, Predicted Price: -0.65
# Actual Price: 0.34, Predicted Price: 0.14
# Actual Price: -0.13, Predicted Price: -0.16
# Actual Price: -0.49, Predicted Price: -0.51
# Actual Price: 0.01, Predicted Price: 0.12
# Actual Price: 0.06, Predicted Price: 0.11
# Actual Price: 0.32, Predicted Price: 0.15
# Actual Price: -0.69, Predicted Price: -0.63
# Actual Price: 0.17, Predicted Price: 0.36
# Actual Price: -0.70, Predicted Price: -0.69
# Actual Price: -0.57, Predicted Price: -0.56
# Actual Price: -0.77, Predicted Price: -0.68
# Actual Price: -0.72, Predicted Price: -0.71
# Actual Price: -0.67, Predicted Price: -0.68
# Actual Price: 0.67, Predicted Price: 0.64
# Actual Price: 0.57, Predicted Price: 0.52
# Actual Price: 0.42, Predicted Price: 0.49
# Actual Price: -0.40, Predicted Price: -0.28
# Actual Price: 0.22, Predicted Price: 0.32
# Actual Price: 0.18, Predicted Price: 0.27
# Actual Price: -0.76, Predicted Price: -0.72
# Actual Price: 0.69, Predicted Price: 0.66
# Actual Price: -0.50, Predicted Price: -0.54
# Actual Price: -0.78, Predicted Price: -0.79
# Actual Price: 0.11, Predicted Price: 0.15
# Actual Price: -0.61, Predicted Price: -0.63
# Actual Price: 0.56, Predicted Price: 0.58
# Actual Price: -0.70, Predicted Price: -0.65
# Actual Price: 0.61, Predicted Price: 0.70
# Actual Price: -0.76, Predicted Price: -0.66
# Actual Price: 0.63, Predicted Price: 0.71
# Actual Price: 0.39, Predicted Price: 0.41
# Actual Price: 0.40, Predicted Price: 0.31
# Actual Price: 0.71, Predicted Price: 0.88
# Actual Price: -0.59, Predicted Price: -0.55
# Actual Price: 0.24, Predicted Price: 0.17
# Actual Price: -0.24, Predicted Price: -0.36
# Actual Price: 0.29, Predicted Price: 0.28
# Actual Price: 0.36, Predicted Price: 0.51
# Actual Price: -0.22, Predicted Price: -0.20
# Actual Price: 0.44, Predicted Price: 0.51
# Actual Price: 0.76, Predicted Price: 0.76
# Actual Price: -0.45, Predicted Price: -0.54
# Actual Price: -0.60, Predicted Price: -0.64
# Actual Price: -0.98, Predicted Price: -0.74
# Actual Price: 0.27, Predicted Price: 0.34
# Actual Price: -0.48, Predicted Price: -0.54
# Actual Price: -0.46, Predicted Price: -0.53
# Actual Price: -0.70, Predicted Price: -0.63
# Actual Price: 0.44, Predicted Price: 0.52
# Actual Price: -0.63, Predicted Price: -0.54
# Actual Price: -0.89, Predicted Price: -0.69
# Actual Price: 0.65, Predicted Price: 0.74
# Actual Price: 0.71, Predicted Price: 0.82
# Actual Price: 0.48, Predicted Price: 0.50
# Actual Price: 0.50, Predicted Price: 0.49
# Actual Price: 0.44, Predicted Price: 0.54
# Actual Price: -0.76, Predicted Price: -0.77
# Actual Price: 0.77, Predicted Price: 0.75
# Actual Price: 0.47, Predicted Price: 0.48
# Actual Price: 0.54, Predicted Price: 0.55
# Actual Price: -0.69, Predicted Price: -0.28
# Actual Price: -0.74, Predicted Price: -0.74
# Actual Price: -0.77, Predicted Price: -0.69
# Actual Price: -0.79, Predicted Price: -0.70
# Actual Price: 0.55, Predicted Price: 0.61
# Actual Price: 0.32, Predicted Price: 0.12
# Actual Price: -0.57, Predicted Price: -0.63
# Actual Price: -0.60, Predicted Price: -0.72
# Actual Price: -0.72, Predicted Price: -0.73
# Actual Price: 0.68, Predicted Price: 0.84
# Actual Price: 0.78, Predicted Price: 0.94
# Actual Price: -0.80, Predicted Price: -0.71
# Actual Price: -0.71, Predicted Price: -0.70
# Actual Price: -0.60, Predicted Price: -0.24
# Actual Price: 0.74, Predicted Price: 0.58
# Actual Price: -0.57, Predicted Price: -0.66
# Actual Price: -0.79, Predicted Price: -0.64
# Actual Price: -0.65, Predicted Price: -0.61
# Actual Price: 0.50, Predicted Price: 0.48
# Actual Price: -0.27, Predicted Price: -0.37
# Actual Price: -0.44, Predicted Price: -0.56
# Actual Price: -0.44, Predicted Price: -0.56
# Actual Price: 0.45, Predicted Price: 0.68
# Actual Price: 0.19, Predicted Price: 0.19
# Actual Price: -0.52, Predicted Price: -0.53
# Actual Price: -0.83, Predicted Price: -0.73
# Actual Price: 0.43, Predicted Price: 0.44
# Actual Price: 0.20, Predicted Price: 0.30
# Actual Price: 0.69, Predicted Price: 0.69
# Actual Price: 0.19, Predicted Price: 0.06
# Actual Price: -0.15, Predicted Price: -0.15
# Actual Price: -0.01, Predicted Price: 0.03
# Actual Price: 0.25, Predicted Price: 0.31
# Actual Price: 0.79, Predicted Price: 0.70
# Actual Price: -0.86, Predicted Price: -0.73
# Actual Price: 0.61, Predicted Price: 0.71
# Actual Price: 0.49, Predicted Price: 0.72
# Actual Price: 0.84, Predicted Price: 0.71
# Actual Price: -0.81, Predicted Price: -0.74
# Actual Price: -0.84, Predicted Price: -0.65
# Actual Price: -0.51, Predicted Price: -0.53
# Actual Price: 0.44, Predicted Price: 0.62
# Actual Price: -0.80, Predicted Price: -0.74
# Actual Price: -0.19, Predicted Price: -0.19
# Actual Price: -0.01, Predicted Price: 0.07
# Actual Price: -0.02, Predicted Price: -0.23
# Actual Price: -0.72, Predicted Price: -0.70
# Actual Price: 0.46, Predicted Price: 0.59
# Actual Price: -0.76, Predicted Price: -0.67
# Actual Price: 0.93, Predicted Price: 0.87
# Actual Price: -0.20, Predicted Price: -0.38
# Actual Price: -0.51, Predicted Price: -0.57
# Actual Price: -0.75, Predicted Price: -0.70
# Actual Price: -0.78, Predicted Price: -0.71
# Actual Price: 0.30, Predicted Price: 0.37
# Actual Price: 0.47, Predicted Price: 0.45
# Actual Price: 0.48, Predicted Price: 0.70
# Actual Price: -0.75, Predicted Price: -0.69
# Actual Price: -0.30, Predicted Price: -0.29
# Actual Price: 0.55, Predicted Price: 0.79
# Actual Price: 0.60, Predicted Price: 0.64
# Actual Price: -0.77, Predicted Price: -0.71
# Actual Price: 0.42, Predicted Price: 0.61
# Actual Price: -0.48, Predicted Price: -0.51
# Actual Price: 0.32, Predicted Price: 0.15
# Actual Price: -0.07, Predicted Price: -0.05
# Actual Price: -0.78, Predicted Price: -0.75
# Actual Price: 0.63, Predicted Price: 0.86
# Actual Price: 0.11, Predicted Price: 0.15
# Actual Price: -0.50, Predicted Price: -0.54
# Actual Price: -0.77, Predicted Price: -0.70
# Actual Price: -0.87, Predicted Price: -0.74
# Actual Price: 0.55, Predicted Price: 0.54
# Actual Price: 0.63, Predicted Price: 0.64
# Actual Price: 0.65, Predicted Price: 0.77
# Actual Price: 0.61, Predicted Price: 0.57
# Actual Price: -0.01, Predicted Price: -0.28
# Actual Price: -0.84, Predicted Price: -0.67
# Actual Price: -0.55, Predicted Price: -0.67
# Actual Price: -0.73, Predicted Price: -0.62
# Actual Price: 0.20, Predicted Price: 0.34
# Actual Price: -0.63, Predicted Price: -0.64
# Actual Price: -0.37, Predicted Price: -0.30
# Actual Price: 0.55, Predicted Price: 0.32
# Actual Price: 0.82, Predicted Price: 0.92
# Actual Price: -0.40, Predicted Price: -0.52
# Actual Price: -0.76, Predicted Price: -0.71
# Actual Price: -0.65, Predicted Price: -0.69
# Actual Price: 0.66, Predicted Price: 0.75
# Actual Price: 0.69, Predicted Price: 0.59
# Actual Price: 0.40, Predicted Price: 0.45
# Actual Price: -0.85, Predicted Price: -0.73
# Actual Price: 0.74, Predicted Price: 0.78
# Actual Price: 0.43, Predicted Price: 0.45
# Actual Price: -0.81, Predicted Price: -0.74
# Actual Price: -0.89, Predicted Price: -0.73
# Actual Price: -0.15, Predicted Price: -0.38
# Actual Price: 0.25, Predicted Price: 0.28
# Actual Price: -0.54, Predicted Price: -0.52
# Actual Price: 0.32, Predicted Price: 0.25
# Actual Price: -0.84, Predicted Price: -0.72
# Actual Price: -0.22, Predicted Price: -0.34
# Actual Price: -0.17, Predicted Price: -0.16
# Actual Price: -0.40, Predicted Price: -0.54
# Actual Price: -0.10, Predicted Price: -0.09
# Actual Price: -0.39, Predicted Price: -0.35
# Actual Price: -0.84, Predicted Price: -0.40
# Actual Price: 0.36, Predicted Price: 0.33
# Actual Price: 0.57, Predicted Price: 0.48
# Actual Price: -0.79, Predicted Price: -0.71
# Actual Price: -0.88, Predicted Price: -0.81
# Actual Price: 0.21, Predicted Price: 0.25
# Actual Price: 0.43, Predicted Price: 0.55
# Actual Price: 0.43, Predicted Price: 0.49
# Actual Price: -0.64, Predicted Price: -0.64
# Actual Price: 0.32, Predicted Price: 0.09
# Actual Price: 0.39, Predicted Price: 0.35
# Actual Price: -0.57, Predicted Price: -0.58
# Actual Price: -0.95, Predicted Price: -0.74
# Actual Price: -0.20, Predicted Price: -0.17
